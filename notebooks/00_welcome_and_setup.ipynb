# %% [markdown]
# # 00 · Welcome and Setup
#
#         [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ashokmanohar-ai/python-basics-learning-lab/blob/main/notebooks/00_welcome_and_setup.ipynb)
#
#         **How to use this notebook:** Read each explanation, run each code cell with `Shift + Enter`,
#         change the examples, and complete every **Try it yourself** activity.
#
#         ## Learning objectives
#
#         - Run Python code in Jupyter or Google Colab
# - Recognize code, Markdown, output, and errors
# - Use the course learning loop

# %% [markdown]
# ## What is Python?
#
# Python is a readable, general-purpose programming language used for automation, web
# development, data analysis, testing, artificial intelligence, and much more. A program is
# a sequence of instructions. Python runs those instructions from top to bottom.
#
# This first program calls the built-in `print()` function. Text values are placed inside quotes.

# %%
print("Hello, Python learner!")
print("I can run this notebook one cell at a time.")

# %% [markdown]
# ## Check the Python environment
#
# The standard-library `sys` module tells us which Python version is running. Colab already
# provides Python, so no installation is required there.

# %%
import platform

print("Python version:", platform.python_version())
print("Platform:", platform.system())

# %% [markdown]
# ## Code cells and Markdown cells
#
# - **Code cells** contain Python and display results.
# - **Markdown cells** contain explanations, headings, and links.
# - Run a cell with the play button or `Shift + Enter`.
# - Restart the runtime if variables become confusing, then choose **Run all**.

# %%
message = "Small experiments build strong skills."
print(message)

# %% [markdown]
# ## Your first experiment
#
# Change the values below. Predict the output before running the cell.

# %%
learner_name = "Ashok"  # Replace with your name
study_minutes = 20
print(f"{learner_name} will practise for {study_minutes} minutes today.")

# %% [markdown]
# ## When something goes wrong
#
# A traceback explains an error. The last line normally contains the most useful message.
# The example below handles a deliberate conversion error so the notebook can continue.

# %%
try:
    int("not-a-number")
except ValueError as error:
    print("Expected learning example:", error)

# %% [markdown]
# ## Wrap-up
#
# You have reached the end of this module. Before moving on:
#
# 1. Explain the main ideas in your own words.
# 2. Change at least one example and predict the result before running it.
# 3. Complete the practice activity without copying the example.
#
# **Tip:** Errors are useful feedback. Read the final line of the traceback first, then inspect
# the highlighted line of code.
