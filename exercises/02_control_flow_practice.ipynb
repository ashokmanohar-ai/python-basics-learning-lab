# %% [markdown]
# # Practice 02 · Conditions and Loops
#
#         [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ashokmanohar-ai/python-basics-learning-lab/blob/main/exercises/02_control_flow_practice.ipynb)
#
#         **How to use this notebook:** Read each explanation, run each code cell with `Shift + Enter`,
#         change the examples, and complete every **Try it yourself** activity.
#
#         ## Learning objectives
#
#         - Practise branching and iteration
# - Test boundary conditions

# %% [markdown]
# ## 1. Number classifier
# Print whether a number is positive, negative, or zero and whether it is even or odd.

# %%
number = -4
# TODO: write the conditions.
print("Complete exercise 1")

# %% [markdown]
# ## 2. Leap year
# A year is a leap year if divisible by 4, except centuries must be divisible by 400.

# %%
year = 2028
# TODO: set is_leap_year to True or False.
is_leap_year = None
print(is_leap_year)

# %% [markdown]
# ## 3. FizzBuzz
# For 1–30 print Fizz for multiples of 3, Buzz for 5, and FizzBuzz for both.

# %%
# TODO: replace this preview with your loop.
for number in range(1, 6):
    print(number)

# %% [markdown]
# ## 4. Sum selected values
# Sum the numbers from 1–100 that are divisible by 3 or 5.

# %%
total = 0
# TODO: loop and update total.
print(total)

# %% [markdown]
# ## 5. Password attempts
# Loop over sample attempts and stop at the correct password. Allow at most three attempts.

# %%
expected = "python123"
attempts = ["password", "python", "python123", "ignored"]
# TODO: use enumerate and break.
print("Complete exercise 5")

# %% [markdown]
# ## Wrap-up
#
# You have reached the end of this module. Before moving on:
#
# 1. Explain the main ideas in your own words.
# 2. Change at least one example and predict the result before running it.
# 3. Complete the practice activity without copying the example.
#
# **Tip:** Errors are useful feedback. Read the final line of the traceback first, then inspect
# the highlighted line of code.
