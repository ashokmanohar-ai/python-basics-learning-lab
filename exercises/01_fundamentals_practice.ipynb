# %% [markdown]
# # Practice 01 · Fundamentals
#
#         [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ashokmanohar-ai/python-basics-learning-lab/blob/main/exercises/01_fundamentals_practice.ipynb)
#
#         **How to use this notebook:** Read each explanation, run each code cell with `Shift + Enter`,
#         change the examples, and complete every **Try it yourself** activity.
#
#         ## Learning objectives
#
#         - Practise variables, types, strings, and operators
# - Check results with small examples

# %% [markdown]
# ## Instructions
#
# Complete each `TODO`. Run the cell with at least two sets of values. If you are stuck for
# more than 15 minutes, review lessons 01–02 before checking the matching solution notebook.

# %% [markdown]
# ## 1. Personal introduction
# Create name, city, and learning-goal variables and print one f-string.

# %%
# TODO: Replace None with your values and build the sentence.
name = None
city = None
learning_goal = None
print("Complete exercise 1")

# %% [markdown]
# ## 2. Rectangle calculator
# Calculate area and perimeter from width and height.

# %%
width = 8
height = 5
# TODO: calculate area and perimeter.
area = None
perimeter = None
print(area, perimeter)

# %% [markdown]
# ## 3. Temperature conversion
# Convert 30°C to Fahrenheit with `(celsius * 9 / 5) + 32`.

# %%
celsius = 30
# TODO
fahrenheit = None
print(fahrenheit)

# %% [markdown]
# ## 4. Time conversion
# Convert 7,385 seconds into hours, remaining minutes, and seconds using `//` and `%`.

# %%
total_seconds = 7385
# TODO
hours = minutes = seconds = None
print(hours, minutes, seconds)

# %% [markdown]
# ## 5. Shopping bill
# Calculate a subtotal, 15% discount, and final total. Format money to two decimal places.

# %%
price = 24.99
quantity = 3
discount_rate = 0.15
# TODO
subtotal = discount = final_total = None
print(subtotal, discount, final_total)

# %% [markdown]
# ## Wrap-up
#
# You have reached the end of this module. Before moving on:
#
# 1. Explain the main ideas in your own words.
# 2. Change at least one example and predict the result before running it.
# 3. Complete the practice activity without copying the example.
#
# **Tip:** Errors are useful feedback. Read the final line of the traceback first, then inspect
# the highlighted line of code.
