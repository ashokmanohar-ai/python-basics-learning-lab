# %% [markdown]
# # Practice 04 · Files, Exceptions, and OOP
#
#         [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ashokmanohar-ai/python-basics-learning-lab/blob/main/exercises/04_files_exceptions_and_oop_practice.ipynb)
#
#         **How to use this notebook:** Read each explanation, run each code cell with `Shift + Enter`,
#         change the examples, and complete every **Try it yourself** activity.
#
#         ## Learning objectives
#
#         - Validate data and handle expected errors
# - Persist simple data
# - Model a small domain with a class

# %% [markdown]
# ## Setup
# These exercises use a temporary directory that is safe in local Jupyter and Colab.

# %%
from pathlib import Path
from tempfile import TemporaryDirectory
import json

temporary_workspace = TemporaryDirectory()
workdir = Path(temporary_workspace.name)

# %% [markdown]
# ## 1. Safe integer
# Return an integer for valid text and a supplied default for invalid text.

# %%
def safe_int(text, default=0):
    # TODO
    return default

print(safe_int("42"), safe_int("unknown", -1))

# %% [markdown]
# ## 2. Save and load tasks
# Write a list of task dictionaries to JSON and load it again.

# %%
tasks = [{"title": "Study Python", "done": False}]
tasks_path = workdir / "tasks.json"
# TODO: write then load the file.
loaded_tasks = []
print(loaded_tasks)

# %% [markdown]
# ## 3. Product class
# Create a Product with name, price, stock, and a `sell(quantity)` method with validation.

# %%
class Product:
    # TODO: implement __init__, sell, and __str__.
    pass

print("Complete Product, then create and sell an item.")

# %% [markdown]
# ## 4. Inventory report
# Write products to JSON as dictionaries and calculate total inventory value.

# %%
# TODO: complete after implementing Product.
print("Complete exercise 4")
temporary_workspace.cleanup()

# %% [markdown]
# ## Wrap-up
#
# You have reached the end of this module. Before moving on:
#
# 1. Explain the main ideas in your own words.
# 2. Change at least one example and predict the result before running it.
# 3. Complete the practice activity without copying the example.
#
# **Tip:** Errors are useful feedback. Read the final line of the traceback first, then inspect
# the highlighted line of code.
