# %% [markdown]
# # Practice 03 · Collections and Functions
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ashokmanohar-ai/python-basics-learning-lab/blob/main/exercises/03_collections_and_functions_practice.ipynb)
#
# **How to use this notebook:** Read each explanation, run each code cell with `Shift + Enter`,
# change the examples, and complete every **Try it yourself** activity.
#
# ## Learning objectives
#
# - Transform lists, dictionaries, sets, and tuples
# - Package logic into testable functions

# %% [markdown]
# ## 1. Clean names
# Write a function that strips whitespace, title-cases names, and removes blank values.

# %%
raw_names = ["  maya", "LEO ", "", "  sam lee  "]

def clean_names(names):
    # TODO
    return []

print(clean_names(raw_names))

# %% [markdown]
# ## 2. Word counts
# Return a dictionary mapping lowercase words to their counts.

# %%
def word_counts(text):
    # TODO
    return {}

print(word_counts("Python practice makes Python progress"))

# %% [markdown]
# ## 3. Unique shared skills
# Return the sorted intersection of two skill collections.

# %%
def shared_skills(first, second):
    # TODO
    return []

print(shared_skills(["Python", "SQL"], ["Git", "Python"]))

# %% [markdown]
# ## 4. Student summary
# Given a list of `(name, score)` tuples, return average, top student, and pass count.

# %%
records = [("Maya", 88), ("Leo", 94), ("Sam", 57)]

def summarise_students(student_records, pass_mark=60):
    # TODO
    return {}

print(summarise_students(records))

# %% [markdown]
# ## 5. Group by first letter
# Return a dictionary whose keys are first letters and values are sorted name lists.

# %%
def group_names(names):
    # TODO
    return {}

print(group_names(["Maya", "Max", "Leo", "Lina", "Sam"]))

# %% [markdown]
# ## Wrap-up
#
# You have reached the end of this module. Before moving on:
#
# 1. Explain the main ideas in your own words.
# 2. Change at least one example and predict the result before running it.
# 3. Complete the practice activity without copying the example.
#
# **Tip:** Errors are useful feedback. Read the final line of the traceback first, then inspect
# the highlighted line of code.
